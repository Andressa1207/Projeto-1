# %% [markdown]
# <a href="https://colab.research.google.com/github/Andressa1207/Projeto-1/blob/main/1_%C2%B0_Projeto_Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Projeto 1
# *Análise dos Dados do Airbnb - Cidade de Amsterdam*
# ## O que é e como funciona o Airbnb?
#
# A plataforma Airbnb funciona como uma rede social. Ela conecta pessoas interessadas em encontrar acomodações boas e baratas onde anfitriões com propriedades disponíveis, alugam suas casas, apartamento ou até quartos. Por ser uma rede social, você deve criar um perfil para utilizá-la. Conforme você fizer reservas ou receber pessoas, você vai receber avaliações,num contexto diferente de hotéis.
#
# Além disso, a plataforma conta desde de 2022 com o Airbnb Cover, uma espécie de “seguro” com proteção contra cancelamentos feitos pelo anfitrião, falsidade nos anúncios e outros problemas. Hoje AirBnb é sucesso mundial!
#
# <center><img alt="Analisando Airbnb" width="50%" src="https://t3.ftcdn.net/jpg/04/04/55/54/240_F_404555405_kC2DiYi6fbvZGraKuXlf1izqNEYv3HCe.jpg"></center>

# %% [markdown]
# ## Obtenção de dados

# %%
# Importa pacotes necessarios 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# !pip install seaborn 

# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# importar o arquivo listings.csv para um DataFrame

df = pd.read_csv('/content/drive/MyDrive/listings.csv',
                  index_col='id')

# %% [markdown]
# ## > Análise dos Dados.
# Dicionario das variáveis.
#
# * id - número de id gerado para identificar o imóvel
# * name - nome da propriedade anunciada
# *host_id - número de id do proprietário (anfitrião) da propriedade
# * host_name - Nome do anfitrião
# * neighbourhood_group - esta coluna não contém nenhum valor válido
# * neighbourhood - nome do bairro
# * latitude - coordenada da latitude da propriedade
# * longitude - coordenada da longitude da propriedade
# * room_type - informa o tipo de quarto que é oferecido
# * price - preço para alugar o imóvel
# * minimum_nights - quantidade mínima de noites para reservar
# * number_of_reviews - número de reviews que a propriedade possui
# * last_review - data do último review
# * reviews_per_month - quantidade de reviews por mês
# * calculated_host_listings_count - quantidade de imóveis do mesmo anfitrião
# * availability_365 - número de dias de disponibilidade dentro de 365 dias

# %%
# mostrar as 5 primeiras entradas
df.head(5)
# Out:
#                                                     name  host_id  host_name  \
# id
# 2818           Quiet Garden View Room & Super Fast Wi-Fi     3159     Daniel
# 20168       Studio with private bathroom in the centre 1    59484  Alexander
# 27886  Romantic, stylish B&B houseboat in canal district    97647       Flip
# 28871                            Comfortable double room   124245      Edwin
# 29051                            Comfortable single room   124245      Edwin
#
#        neighbourhood_group                           neighbourhood  latitude  \
# id
# 2818                   NaN  Oostelijk Havengebied - Indische Buurt  52.36435
# 20168                  NaN                            Centrum-Oost  52.36407
# 27886                  NaN                            Centrum-West  52.38761
# 28871                  NaN                            Centrum-West  52.36775
# 29051                  NaN                            Centrum-Oost  52.36584
#
# ...

# %% [markdown]
# 1- Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?

# %%
# identificar o volume de dados do DataFrame
print("Entradas:\t {}".format(df.shape[0]))
print("Entradas:\t {}\n".format(df.shape[1]))


# verificar as 5 primeiras entradas do dataset
df.dtypes
# Out:
# Entradas:	 6998
# Entradas:	 17
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# # 2- Qual a porcentagem de valores ausentes no dataset?

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum()/df.shape[0]).sort_values(ascending=False)
# Out:
# neighbourhood_group               1.000000
# reviews_per_month                 0.097456
# last_review                       0.097456
# license                           0.003430
# minimum_nights                    0.000000
# number_of_reviews_ltm             0.000000
# availability_365                  0.000000
# calculated_host_listings_count    0.000000
# number_of_reviews                 0.000000
# name                              0.000000
# host_id                           0.000000
# room_type                         0.000000
# longitude                         0.000000
# latitude                          0.000000
# neighbourhood                     0.000000
# host_name                         0.000000
# price                             0.000000
# dtype: float64

# %% [markdown]
# # 3- Qual o tipo de distribuição das variáveis?

# %%
# Plotar histograma 
df.hist(bins=10, figsize=(15,10));

# %%
# ver o resumo estatístico das variáveis numéricas
df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].describe()
# Out:
#              price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  6998.000000     6998.000000        6998.000000        6316.000000
# mean    223.038868        4.157188          48.557445           1.134069
# std     181.018460       19.356066         104.420518           2.396285
# min       0.000000        1.000000           0.000000           0.010000
# 25%     130.000000        2.000000           3.000000           0.270000
# 50%     186.000000        3.000000          12.000000           0.530000
# 75%     270.000000        4.000000          43.000000           1.170000
# max    7900.000000     1001.000000        2310.000000         111.590000
#
#        calculated_host_listings_count  availability_365
# count                     6998.000000       6998.000000
# mean                         1.806516         71.658045
# std                          2.474394        101.903298
# min                          1.000000          0.000000
# ...

# %%
# ver a média da coluna 'price'
df.price.mean()
# Out:
# 223.03886824807088

# %% [markdown]
# 4. Qual a correlação existente entre as variáveis

# %%
# criar uma matriz de correlação
df.corr()
# Out:
# <ipython-input-80-c1c3c11688c3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                  host_id  neighbourhood_group  latitude  \
# host_id                         1.000000                  NaN -0.014917
# neighbourhood_group                  NaN                  NaN       NaN
# latitude                       -0.014917                  NaN  1.000000
# longitude                      -0.010740                  NaN -0.097466
# price                           0.010646                  NaN -0.001436
# minimum_nights                 -0.040923                  NaN -0.012438
# number_of_reviews              -0.081706                  NaN  0.024859
# reviews_per_month               0.145704                  NaN  0.012417
# ...

# %%
# eliminar todas as entradas onde existam valores ausentes em `user_gender`
df_clean = df.dropna(subset=['neighbourhood_group'], axis=0)

# comparar o antes e o depois
print("Antes:\t{}".format(df.shape))
print("Depois:\t{}n".format(df_clean.shape))
# Out:
# Antes:	(6998, 17)
# Depois:	(0, 17)n

# %%
# antes
df_clean.isnull().sum()
# Out:
# name                              0.0
# host_id                           0.0
# host_name                         0.0
# neighbourhood_group               0.0
# neighbourhood                     0.0
# latitude                          0.0
# longitude                         0.0
# room_type                         0.0
# price                             0.0
# minimum_nights                    0.0
# number_of_reviews                 0.0
# last_review                       0.0
# reviews_per_month                 0.0
# calculated_host_listings_count    0.0
# availability_365                  0.0
# number_of_reviews_ltm             0.0
# license                           0.0
# dtype: float64

# %%
# copiar novamente
df_clean = df.copy()

# %%
# ver valores ausentes
df_clean.isnull().sum()
# Out:
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               6998
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                        682
# reviews_per_month                  682
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                             24
# dtype: int64

# %%
# mostrar a matriz de correlação
sns.heatmap(df.corr(),annot=True);
# Out:
# <ipython-input-97-876daee3f55b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# 5. Qual o tipo de imóvel mais alugado no Airbnb?

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df_clean.room_type.value_counts()
# Out:
# Entire home/apt    5154
# Private room       1743
# Hotel room           62
# Shared room          39
# Name: room_type, dtype: int64

# %% [markdown]
# Qual a localidade mais cara do dataset?

# %%
df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
# Out:
# neighbourhood
# Centrum-West                255.953362
# Centrum-Oost                255.323054
# Zuid                        254.877155
# De Pijp - Rivierenbuurt     238.135910
# Oud-Noord                   228.490683
# IJburg - Zeeburgereiland    223.566879
# De Baarsjes - Oud-West      222.558385
# Watergraafsmeer             220.177885
# De Aker - Nieuw Sloten      214.959184
# Westerpark                  211.696466
# Name: price, dtype: float64

# %% [markdown]
# Qual é a média do mínimo de noites para aluguel (minimum_nights)?

# %%
df.minimum_nights.mean()
# Out:
# 4.157187767933696

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ### Para esse projeto escolhi analisar os dados da cidade de Amsterdam, como surgiu e quais os principais pontos turisticos da cidade.
#  Amsterdam surgiu de um pequeno povoado de pescadores, como todas as cidades que ao longo da história se desenvolveram ao lado do mar. Ela
#   foi fundada por volta do século XIII. E foi desenvolvida em volta de uma represa no rio Amstel, no final do século 12. O nome Amstelledamme aparece pela primeira vez na portagem concessionada de Floris V, conde de Holanda, com data 27 de Outubro de 1275.
#
# Amsterdam é a capital da Holanda, conhecida por seu patrimônio artístico,com casas estreitas e com telhados de duas águas, legados esse da era dourada do século XVII na cidade. A cidade possui o museu Van Gogh e também a casa museu onde Anne Frank e sua família se esconderam dos nazistas em um anexo secreto durante a II Guerra Mundial. o Rijksmuseum, com obras de Rembrandt e Vermeer, e o Stedelijk, que privilegia a arte moderna. O ciclismo é uma característica essencial da cidade, que tem grande quantidade de ciclovia,a arquitetura histórica do século XVI e os canais românticos, fazem da capital, o destino mais procurado na Holanda. Amsterdam também é conhecida por suas galerias, bares, parques. O bom de analisar os dados dessa cidade é que pude conhecer melhor e mais profundo, pois Amsterdam é uma cidade onde sempre quis conhecer.
#
# Analisando os dados pude perceber de tinha dados ausentes " outliers" , e consegui tratar esses dados com mais cautela, depois dessa analise consegui reorganizar os dados e tendo  uma vizualização mais ampla consegui trabalhar com mais facilidade.
#
#
# <center><img alt="Analisando Airbnb" width="50%" src="https://images.unsplash.com/photo-1459679749680-18eb1eb37418?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8NHx8YW1zdGVyZGFtfGVufDB8fDB8fHww&auto=format&fit=crop&w=1000&q=60"></center>
